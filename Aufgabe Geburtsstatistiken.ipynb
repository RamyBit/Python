# %%
n = 0
name = "Max"
state = "CA"

with open("data/names.csv","r") as file:
    for line in file:
        data = line.strip().split(",")
        if data[2]== "Year":
            continue
            
        year = int (data[2])
        if data[1] == "Max" and year>= 1950 and year <= 2000 and data[3] == "M" and data[4] == "CA":
            n = n + int(data[5])
            print(n)
            print(data)
# Out:
# 57
# ['587639', 'Max', '1950', 'M', 'CA', '57']
# 112
# ['588509', 'Max', '1951', 'M', 'CA', '55']
# 162
# ['589387', 'Max', '1952', 'M', 'CA', '50']
# 215
# ['590293', 'Max', '1953', 'M', 'CA', '53']
# 264
# ['591280', 'Max', '1954', 'M', 'CA', '49']
# 317
# ['592234', 'Max', '1955', 'M', 'CA', '53']
# 367
# ['593273', 'Max', '1956', 'M', 'CA', '50']
# 435
# ['594266', 'Max', '1957', 'M', 'CA', '68']
# 494
# ['595363', 'Max', '1958', 'M', 'CA', '59']
# 549
# ['596449', 'Max', '1959', 'M', 'CA', '55']
# 612
# ['597534', 'Max', '1960', 'M', 'CA', '63']
# 682
# ['598644', 'Max', '1961', 'M', 'CA', '70']
# 737
# ['599856', 'Max', '1962', 'M', 'CA', '55']
# 801
# ['600998', 'Max', '1963', 'M', 'CA', '64']
# 864
# ['602176', 'Max', '1964', 'M', 'CA', '63']
# 917
# ['603392', 'Max', '1965', 'M', 'CA', '53']
# 981
# ['604549', 'Max', '1966', 'M', 'CA', '64']
# 1044
# ['605698', 'Max', '1967', 'M', 'CA', '63']
# 1109
# ['606887', 'Max', '1968', 'M', 'CA', '65']
# 1153
# ...
