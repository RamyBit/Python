# %%
#!pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.2.54-cp38-cp38-win_amd64.whl (34.7 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ramy\anaconda3\lib\site-packages (from opencv-python) (1.19.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.2.54

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy
import cv2

# %%
img = cv2.imread(r"C:\Users\Ramy\Kursmaterialien\Kursmaterialien\19 - Exkurs Opencv\bild.jpg")

# %%
print(img.shape)
# Out:
# (1000, 1500, 3)

# %%
plt.imshow(img)
plt.show()

# %%
print(img[0][0])
imgc = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(imgc[0][0])
imgg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(imgg.shape)
print(imgg[0][0])
# Out:
# [209 183 171]
# [171 183 209]
# (1000, 1500)
# 182

# %%
plt.imshow(imgc)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(imgg,"gray")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
