# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np 
import cv2

img = cv2.imread(r"C:\Users\Ramy\Kursmaterialien\Kursmaterialien\19 - Exkurs Opencv\bild.jpg")

# %%
print(img [0] [0])
# Out:
# [209 183 171]

# %%
r = np.array([1,2,3,100], dtype="uint8")
r = r + 250
print(r)
# Out:
# [251 252 253  94]

# %%
increased = img + 50

# %%
print(increased[0] [0])
# Out:
# [  3 233 221]

# %%
i = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(i)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
i2 = cv2.cvtColor(increased, cv2.COLOR_BGR2RGB)
plt.imshow(i2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(img.shape)
# Out:
# (1000, 1500, 3)

# %%
z = np.zeros((1000, 1500,3), dtype="uint8") + 50

# %%
i3 = cv2.cvtColor(z, cv2.COLOR_BGR2RGB)
plt.imshow(i3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
i4 = cv2.add(i, z)
print(i [0] [0])
print(i4[0] [0])
# Out:
# [171 183 209]
# [221 233 255]

# %%
plt.imshow(i4)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img2 = img.copy()
cv2.rectangle(img2,(1000,200), (1200,600),(0,0,255), 20)
i5 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(i5)
plt.show()
